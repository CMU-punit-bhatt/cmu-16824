# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/spring22/16824/hw3/vae/
# Out:
# /content/drive/MyDrive/spring22/16824/hw3/vae

# %%
# 16
# !python train.py --model ae_latent --latent-dim 16
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 208.68048}
# 4 {'recon_loss': 208.86113}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 201.4916}
# 9 {'recon_loss': 205.12119}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 195.90405}
# 14 {'recon_loss': 209.53389}
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# 19 {'recon_loss': 192.47604}
# 19 {'recon_loss': 204.0973}
# ...

# %%
# 128
# !python train.py --model ae_latent --latent-dim 128
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 96.70839}
# 4 {'recon_loss': 88.42651}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 64.065094}
# 9 {'recon_loss': 66.03436}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 58.60516}
# 14 {'recon_loss': 57.501007}
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# 19 {'recon_loss': 56.19457}
# 19 {'recon_loss': 56.184105}
# ...

# %%
# 1024
# !python train.py --model ae_latent --latent-dim 1024
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 86.85088}
# 4 {'recon_loss': 77.30631}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 48.602924}
# 9 {'recon_loss': 47.429207}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 36.48309}
# 14 {'recon_loss': 37.23777}
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# 19 {'recon_loss': 27.025023}
# 19 {'recon_loss': 29.813822}
# ...

# %%
# VAE 16
# !python train.py --model vae_latent --latent-dim 16
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 218.96658, 'kl_loss': 30.272451}
# 4 {'recon_loss': 219.3708, 'kl_loss': 30.338953}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 211.28598, 'kl_loss': 30.412859}
# 9 {'recon_loss': 217.5771, 'kl_loss': 30.017828}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 206.32458, 'kl_loss': 30.632948}
# ...

# %%
# VAE 128
# !python train.py --model vae_latent --latent-dim 128
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 158.84367, 'kl_loss': 55.239986}
# 4 {'recon_loss': 154.51428, 'kl_loss': 56.43272}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 134.75821, 'kl_loss': 60.809002}
# 9 {'recon_loss': 131.79094, 'kl_loss': 62.772877}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 126.20527, 'kl_loss': 63.124573}
# ...

# %%
# VAE 1024
# !python train.py --model vae_latent --latent-dim 1024
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 206.6362, 'kl_loss': 60.91444}
# 4 {'recon_loss': 199.70901, 'kl_loss': 58.795727}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 156.72168, 'kl_loss': 56.871323}
# 9 {'recon_loss': 156.02519, 'kl_loss': 57.685608}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 144.19669, 'kl_loss': 58.732426}
# ...

# %%
# Beta - VAE 0.8
# !python train.py --model vae_latent1024_beta_constant --beta 0.8
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 194.11986, 'kl_loss': 71.28725}
# 4 {'recon_loss': 183.77193, 'kl_loss': 71.41653}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 144.67558, 'kl_loss': 65.77959}
# 9 {'recon_loss': 146.68393, 'kl_loss': 65.99789}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 132.31728, 'kl_loss': 68.71207}
# ...

# %%
# Beta - VAE 1.2
# !python train.py --model vae_latent1024_beta_constant --beta 1.2
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 221.11205, 'kl_loss': 55.511406}
# 4 {'recon_loss': 212.04721, 'kl_loss': 55.272766}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 169.22461, 'kl_loss': 49.46473}
# 9 {'recon_loss': 168.33287, 'kl_loss': 49.318188}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 157.44254, 'kl_loss': 50.96868}
# ...

# %%
# Beta - VAE Linear
# !python train.py --model vae_latent1024_beta_linear1
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# #batches train -  196
# #batches val -  40
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# 4 {'recon_loss': 128.21857, 'kl_loss': 179.78387}
# 4 {'recon_loss': 120.29911, 'kl_loss': 171.41454}
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# 9 {'recon_loss': 107.463356, 'kl_loss': 112.13489}
# 9 {'recon_loss': 107.30819, 'kl_loss': 109.44077}
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# 14 {'recon_loss': 112.81845, 'kl_loss': 88.04203}
# ...
